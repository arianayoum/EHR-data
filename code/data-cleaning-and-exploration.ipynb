# %%
# Load packages
import pandas as pd
import os

# %%
# Load dataset
path = os.getcwd()
all_df = pd.ExcelFile('./hospital-spending-series-b-2005-2022-data-tables-en.xlsx')
print(all_df.sheet_names)
# Out:
# ['Instructions', 'Table of contents', 'Canada (excl. Que., Nun.)', 'N.L.', 'P.E.I.', 'N.S.', 'N.B.', 'Ont.', 'Man.', 'Sask.', 'Alta.', 'B.C.', 'Y.T.', 'N.W.T.', 'Definitions', 'Contact info']

# %%
# Parse subsheets of interest
can_df = pd.read_excel(all_df, 'Canada (excl. Que., Nun.)', skiprows=4)
on_df = pd.read_excel(all_df, 'Ont.', skiprows=4)
print(can_df)
# Out:
#                                                  Year Administrative Services  \
# 0                                          2005–2006                   1776.3
# 1                                          2006–2007                   1936.8
# 2                                           2007–2008                  2075.3
# 3                                          2008–2009                   2230.3
# 4                                           2009–2010                    2295
# ..                                                ...                     ...
# 83                                               Note                     NaN
# 84                               n/a: Not applicable.                     NaN
# 85                                             Source                     NaN
# 86  Canadian MIS Database, 2005 to 2022, Canadian ...                     NaN
# 87       End of worksheet (back to Table of contents)                     NaN
#
#    Support Services Nursing Inpatient Services Intensive Care Nursing Unit  \
# 0            5631.5                     6164.1                        1449
# 1            6037.6                     6591.1                      1564.6
# 2            6484.2                       7127                      1693.3
# 3            6937.3                     7507.7                      1802.6
# 4            7242.2                     7890.5                      1886.9
# ..              ...                        ...                         ...
# 83              NaN                        NaN                         NaN
# 84              NaN                        NaN                         NaN
# 85              NaN                        NaN                         NaN
# 86              NaN                        NaN                         NaN
# 87              NaN                        NaN                         NaN
#
#    Operating Room Long-Term Care Nursing Unit Emergency  \
# 0          2006.7                        1273    1195.5
# 1          2167.9                      1335.9    1312.1
# 2          2353.8                      1369.6    1448.1
# 3          2490.3                      1430.8    1551.1
# 4          2859.4                        1209    1661.4
# ..            ...                         ...       ...
# 83            NaN                         NaN       NaN
# 84            NaN                         NaN       NaN
# 85            NaN                         NaN       NaN
# 86            NaN                         NaN       NaN
# 87            NaN                         NaN       NaN
#
#    Other Ambulatory Care Services Medical Imaging  \
# 0                          2524.5          1666.6
# 1                          2700.9          1771.1
# 2                          2963.4          1857.6
# 3                          3161.7          2010.6
# 4                          3059.7          1976.6
# ..                            ...             ...
# 83                            NaN             NaN
# 84                            NaN             NaN
# 85                            NaN             NaN
# 86                            NaN             NaN
# 87                            NaN             NaN
#
#    Other Diagnostic and Therapeutic Community Health Services  \
# 0                              4081                     774.9
# 1                            4379.5                     797.6
# 2                            4605.4                     837.2
# 3                            4927.2                     920.4
# 4                            5356.1                    1290.4
# ..                              ...                       ...
# 83                              NaN                       NaN
# 84                              NaN                       NaN
# 85                              NaN                       NaN
# 86                              NaN                       NaN
# 87                              NaN                       NaN
#
#    Research, Education \nand Other     Total Unnamed: 14
# 0                            2822.9    31366         NaN
# 1                            2539.1    33134         NaN
# 2                            2695.8  35510.7         NaN
# 3                              2962  37932.2         NaN
# 4                            3315.6  40042.8         NaN
# ..                              ...      ...         ...
# 83                              NaN      NaN         NaN
# 84                              NaN      NaN         NaN
# 85                              NaN      NaN         NaN
# 86                              NaN      NaN         NaN
# 87                              NaN      NaN         NaN
#
# [88 rows x 15 columns]

# %% [markdown]
# # Data Extraction and Cleaning
# In the code below, I further parse the data and then I check if it needs cleaning (e.g. are there missing values?)

# %% [markdown]
# ## Net expenses by year
# Hospital spending by service area in millions of current dollars.

# %%
# Canada
can_expenses = can_df.loc[0:17]

# Drop columns containing any NaN values
can_expenses_cleaned = can_expenses.dropna(axis=1, how='all')
print(can_expenses_cleaned)
# Out:
#           Year Administrative Services Support Services  \
# 0   2005–2006                   1776.3           5631.5
# 1   2006–2007                   1936.8           6037.6
# 2    2007–2008                  2075.3           6484.2
# 3   2008–2009                   2230.3           6937.3
# 4    2009–2010                    2295           7242.2
# 5   2010–2011                   2223.3           7486.7
# 6    2011–2012                  2308.2           7834.3
# 7   2012–2013                   2367.6           8133.9
# 8    2013–2014                  2375.6           8438.2
# 9    2014–2015                  2389.8           8648.2
# 10   2015–2016                    2441             8899
# 11   2016–2017                  2503.7           9052.3
# 12   2017–2018                  2559.9           9226.2
# 13   2018–2019                    2675           9540.3
# 14   2019–2020                  2681.1           9853.1
# 15   2020–2021                  3015.6          10825.7
# 16   2021–2022                  3108.1          11427.6
# 17   2022–2023                  3351.1          12304.6
#
#    Nursing Inpatient Services Intensive Care Nursing Unit Operating Room  \
# 0                      6164.1                        1449         2006.7
# 1                      6591.1                      1564.6         2167.9
# 2                        7127                      1693.3         2353.8
# 3                      7507.7                      1802.6         2490.3
# 4                      7890.5                      1886.9         2859.4
# 5                        8177                      1929.2         2955.5
# 6                      8548.7                      1991.3         3057.8
# 7                        8907                        2075         3140.9
# 8                      9086.7                      2099.8         3245.4
# 9                      9334.4                      2181.4         3304.6
# 10                     9521.3                      2224.2         3341.5
# 11                     9617.9                        2261         3402.7
# 12                     9876.9                      2338.8         3515.6
# 13                    10206.4                      2408.6         3677.5
# 14                    10548.7                      2515.2         3781.5
# 15                    11169.2                      2706.1         3692.5
# 16                    11801.3                      2971.4         3957.4
# 17                    12841.6                      3024.7         4483.8
#
#    Long-Term Care Nursing Unit Emergency Other Ambulatory Care Services  \
# 0                         1273    1195.5                         2524.5
# 1                       1335.9    1312.1                         2700.9
# 2                       1369.6    1448.1                         2963.4
# 3                       1430.8    1551.1                         3161.7
# 4                         1209    1661.4                         3059.7
# 5                       1255.2    1718.5                         3239.7
# 6                       1238.1    1815.5                         3419.3
# 7                       1206.5    1879.1                         3444.1
# 8                       1125.2    1978.3                         3572.9
# 9                       1100.7    2063.4                         3722.3
# 10                      1099.2    2125.4                         3874.8
# 11                      1059.7    2194.2                           4010
# 12                      1082.4    2281.3                         4187.5
# 13                      1087.4    2359.1                         4366.3
# 14                      1134.9    2482.9                         4725.2
# 15                      1214.1    2681.4                         4999.6
# 16                      1303.8    2840.5                           5288
# 17                      1317.3    3133.3                         5723.4
#
#    Medical Imaging Other Diagnostic and Therapeutic Community Health Services  \
# 0           1666.6                             4081                     774.9
# 1           1771.1                           4379.5                     797.6
# 2           1857.6                           4605.4                     837.2
# 3           2010.6                           4927.2                     920.4
# 4           1976.6                           5356.1                    1290.4
# 5           2082.6                           5397.4                    1362.3
# 6           2083.5                           5588.8                    1311.9
# 7             2126                           5780.5                    1344.4
# 8           2167.2                             6021                    1493.6
# 9           2222.1                           6201.5                    1593.2
# 10          2272.5                           6448.2                    1704.8
# 11          2318.3                           6433.5                    1764.3
# 12          2356.7                           6708.9                    1858.2
# 13          2424.9                           6786.4                    1998.4
# 14          2552.8                           7168.6                    2016.3
# 15          2621.5                           7502.3                    2500.8
# 16          2805.2                           7993.7                    2850.5
# 17          2950.4                           8231.4                    2809.6
#
#    Research, Education \nand Other     Total
# 0                            2822.9    31366
# 1                            2539.1    33134
# 2                            2695.8  35510.7
# 3                              2962  37932.2
# 4                            3315.6  40042.8
# 5                            3537.8  41365.3
# 6                            3788.6  42985.9
# 7                            4159.6  44564.7
# 8                            4317.3  45921.3
# 9                            4551.1  47312.6
# 10                           4552.8  48504.6
# 11                           4832.7  49450.4
# 12                           5204.9  51197.2
# 13                           5309.5  52839.9
# 14                           5657.2  55117.6
# 15                           5976.8  58905.7
# 16                           6101.7  62449.2
# 17                           6414.5  66585.5

# %%
# Ontario
on_expenses = on_df.loc[0:17]

# Drop columns containing any NaN values
on_expenses_cleaned = on_expenses.dropna(axis=1, how='all')
print(on_expenses_cleaned)
# Out:
#           Year Administrative Services Support Services  \
# 0   2005–2006                    978.9           2707.6
# 1   2006–2007                   1062.8             2827
# 2    2007–2008                  1146.7           3006.4
# 3   2008–2009                   1211.7           3164.6
# 4    2009–2010                  1278.1           3277.4
# 5   2010–2011                     1279           3349.6
# 6    2011–2012                  1294.8           3488.8
# 7   2012–2013                   1311.9           3600.9
# 8    2013–2014                    1337           3712.9
# 9    2014–2015                  1322.9           3733.5
# 10   2015–2016                  1360.3           3828.1
# 11   2016–2017                    1372           3926.7
# 12   2017–2018                  1431.2           4008.1
# 13   2018–2019                  1477.6           4133.5
# 14   2019–2020                  1520.1           4242.4
# 15   2020–2021                  1809.2           5058.5
# 16   2021–2022                  1838.7           5159.9
# 17   2022–2023                  1942.7           5354.7
#
#    Nursing Inpatient Services Intensive Care Nursing Unit Operating Room  \
# 0                      2813.7                       777.7          960.9
# 1                      2970.9                       836.1         1033.4
# 2                        3215                       918.6         1116.6
# 3                      3309.2                       949.6         1144.7
# 4                      3442.1                       973.6         1332.6
# 5                      3534.5                       943.3         1361.4
# 6                      3669.2                       982.4         1410.9
# 7                      3762.8                      1007.5         1429.5
# 8                      3829.8                      1000.3         1465.1
# 9                      3892.7                      1014.4         1483.1
# 10                       3940                        1038         1492.5
# 11                     4014.6                        1053         1522.8
# 12                     4158.8                      1101.5         1574.6
# 13                     4371.3                      1145.7         1645.3
# 14                     4531.9                      1205.4         1686.9
# 15                     4836.9                      1327.4         1625.9
# 16                     5069.8                      1417.1         1748.1
# 17                     5612.7                      1460.4         2017.3
#
#    Long-Term Care Nursing Unit Emergency Other Ambulatory Care Services  \
# 0                        590.8     611.4                         1355.5
# 1                        605.8       654                         1435.4
# 2                        639.3     714.5                         1606.4
# 3                          680       743                           1648
# 4                        554.8       794                         1520.8
# 5                        545.9     825.2                         1573.6
# 6                        565.1     856.8                         1631.2
# 7                          572     874.1                         1711.2
# 8                        567.7     905.9                         1755.2
# 9                        560.2     933.2                         1843.6
# 10                       566.3     952.9                         1911.2
# 11                       564.3     976.9                         1912.3
# 12                       568.6    1026.8                         2000.8
# 13                       579.3    1064.9                           2121
# 14                       599.8    1119.3                         2318.8
# 15                       648.8    1178.1                           2457
# 16                       689.3    1231.5                         2603.6
# 17                       721.2      1394                         2884.6
#
#    Medical Imaging Other Diagnostic and Therapeutic Community Health Services  \
# 0              922                           1930.2                     430.3
# 1            972.7                           2033.7                     455.6
# 2           1019.4                           2142.3                     495.7
# 3           1073.4                           2306.5                     523.1
# 4           1104.4                           2395.1                     698.5
# 5           1112.3                             2444                       730
# 6           1129.3                           2510.6                     751.7
# 7           1149.1                           2582.6                     782.8
# 8           1172.7                           2678.9                     839.7
# 9             1191                             2754                     891.8
# 10          1213.9                           2837.9                     920.3
# 11          1235.9                           2906.4                     957.1
# 12          1274.1                           3013.6                    1016.3
# 13          1314.1                           3119.3                    1081.5
# 14          1366.1                           3250.3                    1142.8
# 15          1403.3                           3409.8                    1585.2
# 16          1507.4                           3592.6                    1778.6
# 17          1592.6                           3737.7                    1719.9
#
#    Research, Education \nand Other     Total
# 0                            1405.9  15484.9
# 1                            1454.9  16342.1
# 2                            1565.8  17586.6
# 3                              1750  18503.9
# 4                            1819.6  19191.1
# 5                            1895.8  19594.6
# 6                            2084.8  20375.5
# 7                            2242.4  21026.8
# 8                            2379.1  21644.3
# 9                            2513.2  22133.7
# 10                           2743.5  22804.9
# 11                           2778.7  23220.8
# 12                           2981.6  24155.9
# 13                           3050.3    25104
# 14                           3300.2  26284.2
# 15                           3403.9  28743.8
# 16                           3551.7  30188.4
# 17                           4012.6  32450.4

# %% [markdown]
# ## Annual percentage change by year
# Hospital spending by service area in millions of current dollars

# %%
# Canada
can_percentchange = can_df.loc[20:37] 

# Drop columns containing any NaN values
can_percentchange_cleaned = can_percentchange.dropna(axis=1, how='all')
print(can_percentchange_cleaned)
# Out:
#           Year Administrative Services Support Services  \
# 20  2005–2006                      NaN              NaN
# 21  2006–2007                        9              7.2
# 22   2007–2008                     7.2              7.4
# 23  2008–2009                      7.5                7
# 24   2009–2010                     2.9              4.4
# 25  2010–2011                     -3.1              3.4
# 26   2011–2012                     3.8              4.6
# 27  2012–2013                      2.6              3.8
# 28   2013–2014                     0.3              3.7
# 29   2014–2015                     0.6              2.5
# 30   2015–2016                     2.1              2.9
# 31   2016–2017                     2.6              1.7
# 32   2017–2018                     2.2              1.9
# 33   2018–2019                     4.5              3.4
# 34   2019–2020                     0.2              3.3
# 35   2020–2021                    12.5              9.9
# 36   2021–2022                     3.1              5.6
# 37   2022–2023                     7.8              7.7
#
#    Nursing Inpatient Services Intensive Care Nursing Unit Operating Room  \
# 20                        NaN                         NaN            NaN
# 21                        6.9                           8              8
# 22                        8.1                         8.2            8.6
# 23                        5.3                         6.5            5.8
# 24                        5.1                         4.7           14.8
# 25                        3.6                         2.2            3.4
# 26                        4.5                         3.2            3.5
# 27                        4.2                         4.2            2.7
# 28                          2                         1.2            3.3
# 29                        2.7                         3.9            1.8
# 30                          2                           2            1.1
# 31                          1                         1.7            1.8
# 32                        2.7                         3.4            3.3
# 33                        3.3                           3            4.6
# 34                        3.4                         4.4            2.8
# 35                        5.9                         7.6           -2.4
# 36                        5.7                         9.8            7.2
# 37                        8.8                         1.8           13.3
#
#    Long-Term Care Nursing Unit Emergency Other Ambulatory Care Services  \
# 20                         NaN       NaN                            NaN
# 21                         4.9       9.7                              7
# 22                         2.5      10.4                            9.7
# 23                         4.5       7.1                            6.7
# 24                       -15.5       7.1                           -3.2
# 25                         3.8       3.4                            5.9
# 26                        -1.4       5.6                            5.5
# 27                        -2.5       3.5                            0.7
# 28                        -6.7       5.3                            3.7
# 29                        -2.2       4.3                            4.2
# 30                        -0.1         3                            4.1
# 31                        -3.6       3.2                            3.5
# 32                         2.1         4                            4.4
# 33                         0.5       3.4                            4.3
# 34                         4.4       5.2                            8.2
# 35                           7         8                            5.8
# 36                         7.4       5.9                            5.8
# 37                           1      10.3                            8.2
#
#    Medical Imaging Other Diagnostic and Therapeutic Community Health Services  \
# 20             NaN                              NaN                       NaN
# 21             6.3                              7.3                       2.9
# 22             4.9                              5.2                         5
# 23             8.2                                7                       9.9
# 24            -1.7                              8.7                      40.2
# 25             5.4                              0.8                       5.6
# 26               0                              3.5                      -3.7
# 27               2                              3.4                       2.5
# 28             1.9                              4.2                      11.1
# 29             2.5                                3                       6.7
# 30             2.3                                4                         7
# 31               2                             -0.2                       3.5
# 32             1.7                              4.3                       5.3
# 33             2.9                              1.2                       7.5
# 34             5.3                              5.6                       0.9
# 35             2.7                              4.7                        24
# 36               7                              6.6                        14
# 37             5.2                                3                      -1.4
#
#    Research, Education \nand Other  Total
# 20                              NaN   NaN
# 21                            -10.1   5.6
# 22                              6.2   7.2
# 23                              9.9   6.8
# 24                             11.9   5.6
# 25                              6.7   3.3
# 26                              7.1   3.9
# 27                              9.8   3.7
# 28                              3.8     3
# 29                              5.4     3
# 30                                0   2.5
# 31                              6.1   1.9
# 32                              7.7   3.5
# 33                                2   3.2
# 34                              6.5   4.3
# 35                              5.6   6.9
# 36                              2.1     6
# 37                              5.1   6.6

# %%
# Ontario
on_percentchange = on_df.loc[20:37]
print(on_percentchange)

# Drop columns containing any NaN values
on_percentchange_cleaned = on_percentchange.dropna(axis=1, how='all')
print(on_percentchange_cleaned)
# Out:
#           Year Administrative Services Support Services  \
# 20  2005–2006                      NaN              NaN
# 21  2006–2007                      8.6              4.4
# 22   2007–2008                     7.9              6.3
# 23  2008–2009                      5.7              5.3
# 24   2009–2010                     5.5              3.6
# 25  2010–2011                      0.1              2.2
# 26   2011–2012                     1.2              4.2
# 27  2012–2013                      1.3              3.2
# 28   2013–2014                     1.9              3.1
# 29   2014–2015                    -1.1              0.6
# 30   2015–2016                     2.8              2.5
# 31   2016–2017                     0.9              2.6
# 32   2017–2018                     4.3              2.1
# 33   2018–2019                     3.2              3.1
# 34   2019–2020                     2.9              2.6
# 35   2020–2021                      19             19.2
# 36   2021–2022                     1.6                2
# 37   2022–2023                     5.7              3.8
#
#    Nursing Inpatient Services Intensive Care Nursing Unit Operating Room  \
# 20                        NaN                         NaN            NaN
# 21                        5.6                         7.5            7.6
# 22                        8.2                         9.9              8
# 23                        2.9                         3.4            2.5
# 24                          4                         2.5           16.4
# 25                        2.7                        -3.1            2.2
# 26                        3.8                         4.1            3.6
# 27                        2.6                         2.6            1.3
# 28                        1.8                        -0.7            2.5
# 29                        1.6                         1.4            1.2
# 30                        1.2                         2.3            0.6
# 31                        1.9                         1.4              2
# 32                        3.6                         4.6            3.4
# 33                        5.1                           4            4.5
# 34                        3.7                         5.2            2.5
# 35                        6.7                        10.1           -3.6
# 36                        4.8                         6.8            7.5
# 37                       10.7                         3.1           15.4
#
#    Long-Term Care Nursing Unit Emergency Other Ambulatory Care Services  \
# 20                         NaN       NaN                            NaN
# 21                         2.5         7                            5.9
# 22                         5.5       9.3                           11.9
# 23                         6.4         4                            2.6
# 24                       -18.4       6.9                           -7.7
# 25                        -1.6       3.9                            3.5
# 26                         3.5       3.8                            3.7
# 27                         1.2         2                            4.9
# 28                        -0.7       3.6                            2.6
# 29                        -1.3         3                              5
# 30                         1.1       2.1                            3.7
# 31                        -0.3       2.5                            0.1
# 32                         0.7       5.1                            4.6
# 33                         1.9       3.7                              6
# 34                         3.5       5.1                            9.3
# 35                         8.2       5.2                              6
# 36                         6.2       4.5                              6
# 37                         4.6      13.2                           10.8
#
#    Medical Imaging  ... Unnamed: 16374 Unnamed: 16375 Unnamed: 16376  \
# 20             NaN  ...            NaN            NaN            NaN
# 21             5.5  ...            NaN            NaN            NaN
# 22             4.8  ...            NaN            NaN            NaN
# 23             5.3  ...            NaN            NaN            NaN
# 24             2.9  ...            NaN            NaN            NaN
# 25             0.7  ...            NaN            NaN            NaN
# 26             1.5  ...            NaN            NaN            NaN
# 27             1.7  ...            NaN            NaN            NaN
# 28             2.1  ...            NaN            NaN            NaN
# 29             1.6  ...            NaN            NaN            NaN
# 30             1.9  ...            NaN            NaN            NaN
# 31             1.8  ...            NaN            NaN            NaN
# 32             3.1  ...            NaN            NaN            NaN
# 33             3.1  ...            NaN            NaN            NaN
# 34               4  ...            NaN            NaN            NaN
# 35             2.7  ...            NaN            NaN            NaN
# 36             7.4  ...            NaN            NaN            NaN
# 37             5.7  ...            NaN            NaN            NaN
#
#    Unnamed: 16377 Unnamed: 16378 Unnamed: 16379 Unnamed: 16380 Unnamed: 16381  \
# 20            NaN            NaN            NaN            NaN            NaN
# 21            NaN            NaN            NaN            NaN            NaN
# 22            NaN            NaN            NaN            NaN            NaN
# 23            NaN            NaN            NaN            NaN            NaN
# 24            NaN            NaN            NaN            NaN            NaN
# 25            NaN            NaN            NaN            NaN            NaN
# 26            NaN            NaN            NaN            NaN            NaN
# 27            NaN            NaN            NaN            NaN            NaN
# 28            NaN            NaN            NaN            NaN            NaN
# 29            NaN            NaN            NaN            NaN            NaN
# 30            NaN            NaN            NaN            NaN            NaN
# 31            NaN            NaN            NaN            NaN            NaN
# 32            NaN            NaN            NaN            NaN            NaN
# 33            NaN            NaN            NaN            NaN            NaN
# 34            NaN            NaN            NaN            NaN            NaN
# 35            NaN            NaN            NaN            NaN            NaN
# 36            NaN            NaN            NaN            NaN            NaN
# 37            NaN            NaN            NaN            NaN            NaN
#
#    Unnamed: 16382 Unnamed: 16383
# 20            NaN            NaN
# 21            NaN            NaN
# 22            NaN            NaN
# 23            NaN            NaN
# 24            NaN            NaN
# 25            NaN            NaN
# 26            NaN            NaN
# 27            NaN            NaN
# 28            NaN            NaN
# 29            NaN            NaN
# 30            NaN            NaN
# 31            NaN            NaN
# 32            NaN            NaN
# 33            NaN            NaN
# 34            NaN            NaN
# 35            NaN            NaN
# 36            NaN            NaN
# 37            NaN            NaN
#
# [18 rows x 16384 columns]
#           Year Administrative Services Support Services  \
# 20  2005–2006                      NaN              NaN
# 21  2006–2007                      8.6              4.4
# 22   2007–2008                     7.9              6.3
# 23  2008–2009                      5.7              5.3
# 24   2009–2010                     5.5              3.6
# 25  2010–2011                      0.1              2.2
# 26   2011–2012                     1.2              4.2
# 27  2012–2013                      1.3              3.2
# 28   2013–2014                     1.9              3.1
# 29   2014–2015                    -1.1              0.6
# 30   2015–2016                     2.8              2.5
# 31   2016–2017                     0.9              2.6
# 32   2017–2018                     4.3              2.1
# 33   2018–2019                     3.2              3.1
# 34   2019–2020                     2.9              2.6
# 35   2020–2021                      19             19.2
# 36   2021–2022                     1.6                2
# 37   2022–2023                     5.7              3.8
#
#    Nursing Inpatient Services Intensive Care Nursing Unit Operating Room  \
# 20                        NaN                         NaN            NaN
# 21                        5.6                         7.5            7.6
# 22                        8.2                         9.9              8
# 23                        2.9                         3.4            2.5
# 24                          4                         2.5           16.4
# 25                        2.7                        -3.1            2.2
# 26                        3.8                         4.1            3.6
# 27                        2.6                         2.6            1.3
# 28                        1.8                        -0.7            2.5
# 29                        1.6                         1.4            1.2
# 30                        1.2                         2.3            0.6
# 31                        1.9                         1.4              2
# 32                        3.6                         4.6            3.4
# 33                        5.1                           4            4.5
# 34                        3.7                         5.2            2.5
# 35                        6.7                        10.1           -3.6
# 36                        4.8                         6.8            7.5
# 37                       10.7                         3.1           15.4
#
#    Long-Term Care Nursing Unit Emergency Other Ambulatory Care Services  \
# 20                         NaN       NaN                            NaN
# 21                         2.5         7                            5.9
# 22                         5.5       9.3                           11.9
# 23                         6.4         4                            2.6
# 24                       -18.4       6.9                           -7.7
# 25                        -1.6       3.9                            3.5
# 26                         3.5       3.8                            3.7
# 27                         1.2         2                            4.9
# 28                        -0.7       3.6                            2.6
# 29                        -1.3         3                              5
# 30                         1.1       2.1                            3.7
# 31                        -0.3       2.5                            0.1
# 32                         0.7       5.1                            4.6
# 33                         1.9       3.7                              6
# 34                         3.5       5.1                            9.3
# 35                         8.2       5.2                              6
# 36                         6.2       4.5                              6
# 37                         4.6      13.2                           10.8
#
#    Medical Imaging Other Diagnostic and Therapeutic Community Health Services  \
# 20             NaN                              NaN                       NaN
# 21             5.5                              5.4                       5.9
# 22             4.8                              5.3                       8.8
# 23             5.3                              7.7                       5.5
# 24             2.9                              3.8                      33.5
# 25             0.7                                2                       4.5
# 26             1.5                              2.7                         3
# 27             1.7                              2.9                       4.1
# 28             2.1                              3.7                       7.3
# 29             1.6                              2.8                       6.2
# 30             1.9                                3                       3.2
# 31             1.8                              2.4                         4
# 32             3.1                              3.7                       6.2
# 33             3.1                              3.5                       6.4
# 34               4                              4.2                       5.7
# 35             2.7                              4.9                      38.7
# 36             7.4                              5.4                      12.2
# 37             5.7                                4                      -3.3
#
#    Research, Education \nand Other  Total
# 20                              NaN   NaN
# 21                              3.5   5.5
# 22                              7.6   7.6
# 23                             11.8   5.2
# 24                                4   3.7
# 25                              4.2   2.1
# 26                               10     4
# 27                              7.6   3.2
# 28                              6.1   2.9
# 29                              5.6   2.3
# 30                              9.2     3
# 31                              1.3   1.8
# 32                              7.3     4
# 33                              2.3   3.9
# 34                              8.2   4.7
# 35                              3.1   9.4
# 36                              4.3     5
# 37                               13   7.5

# %% [markdown]
# ## Percentage by Year
# Percentage distribution of hospital spending by service area

# %%
# Canada
can_service = can_df.loc[45:62]

# Drop columns containing any NaN values
can_service_cleaned = can_service.dropna(axis=1, how='all')
print(can_service_cleaned)
# Out:
#           Year Administrative Services Support Services  \
# 45  2005–2006                      5.7               18
# 46  2006–2007                      5.8             18.2
# 47   2007–2008                     5.8             18.3
# 48  2008–2009                      5.9             18.3
# 49   2009–2010                     5.7             18.1
# 50  2010–2011                      5.4             18.1
# 51   2011–2012                     5.4             18.2
# 52  2012–2013                      5.3             18.3
# 53   2013–2014                     5.2             18.4
# 54   2014–2015                     5.1             18.3
# 55   2015–2016                       5             18.3
# 56   2016–2017                     5.1             18.3
# 57   2017–2018                       5               18
# 58   2018–2019                     5.1             18.1
# 59   2019–2020                     4.9             17.9
# 60   2020–2021                     5.1             18.4
# 61   2021–2022                       5             18.3
# 62   2022–2023                       5             18.5
#
#    Nursing Inpatient Services Intensive Care Nursing Unit Operating Room  \
# 45                       19.7                         4.6            6.4
# 46                       19.9                         4.7            6.5
# 47                       20.1                         4.8            6.6
# 48                       19.8                         4.8            6.6
# 49                       19.7                         4.7            7.1
# 50                       19.8                         4.7            7.1
# 51                       19.9                         4.6            7.1
# 52                         20                         4.7              7
# 53                       19.8                         4.6            7.1
# 54                       19.7                         4.6              7
# 55                       19.6                         4.6            6.9
# 56                       19.4                         4.6            6.9
# 57                       19.3                         4.6            6.9
# 58                       19.3                         4.6              7
# 59                       19.1                         4.6            6.9
# 60                         19                         4.6            6.3
# 61                       18.9                         4.8            6.3
# 62                       19.3                         4.5            6.7
#
#    Long-Term Care Nursing Unit Emergency Other Ambulatory Care Services  \
# 45                         4.1       3.8                              8
# 46                           4         4                            8.2
# 47                         3.9       4.1                            8.3
# 48                         3.8       4.1                            8.3
# 49                           3       4.1                            7.6
# 50                           3       4.2                            7.8
# 51                         2.9       4.2                              8
# 52                         2.7       4.2                            7.7
# 53                         2.5       4.3                            7.8
# 54                         2.3       4.4                            7.9
# 55                         2.3       4.4                              8
# 56                         2.1       4.4                            8.1
# 57                         2.1       4.5                            8.2
# 58                         2.1       4.5                            8.3
# 59                         2.1       4.5                            8.6
# 60                         2.1       4.6                            8.5
# 61                         2.1       4.5                            8.5
# 62                           2       4.7                            8.6
#
#    Medical Imaging Other Diagnostic and Therapeutic Community Health Services  \
# 45             5.3                               13                       2.5
# 46             5.3                             13.2                       2.4
# 47             5.2                               13                       2.4
# 48             5.3                               13                       2.4
# 49             4.9                             13.4                       3.2
# 50               5                               13                       3.3
# 51             4.8                               13                       3.1
# 52             4.8                               13                         3
# 53             4.7                             13.1                       3.3
# 54             4.7                             13.1                       3.4
# 55             4.7                             13.3                       3.5
# 56             4.7                               13                       3.6
# 57             4.6                             13.1                       3.6
# 58             4.6                             12.8                       3.8
# 59             4.6                               13                       3.7
# 60             4.5                             12.7                       4.2
# 61             4.5                             12.8                       4.6
# 62             4.4                             12.4                       4.2
#
#    Research, Education \nand Other  Total
# 45                                9   100
# 46                              7.7   100
# 47                              7.6   100
# 48                              7.8   100
# 49                              8.3   100
# 50                              8.6   100
# 51                              8.8   100
# 52                              9.3   100
# 53                              9.4   100
# 54                              9.6   100
# 55                              9.4   100
# 56                              9.8   100
# 57                             10.2   100
# 58                               10   100
# 59                             10.3   100
# 60                             10.1   100
# 61                              9.8   100
# 62                              9.6   100

# %%
# Ontario
on_service = on_df.loc[45:62]

# Drop columns containing any NaN values
on_service_cleaned = on_service.dropna(axis=1, how='all')
print(on_service_cleaned)
# Out:
#           Year Administrative Services Support Services  \
# 45  2005–2006                      6.3             17.5
# 46  2006–2007                      6.5             17.3
# 47   2007–2008                     6.5             17.1
# 48  2008–2009                      6.5             17.1
# 49   2009–2010                     6.7             17.1
# 50  2010–2011                      6.5             17.1
# 51   2011–2012                     6.4             17.1
# 52  2012–2013                      6.2             17.1
# 53   2013–2014                     6.2             17.2
# 54   2014–2015                       6             16.9
# 55   2015–2016                       6             16.8
# 56   2016–2017                     5.9             16.9
# 57   2017–2018                     5.9             16.6
# 58   2018–2019                     5.9             16.5
# 59   2019–2020                     5.8             16.1
# 60   2020–2021                     6.3             17.6
# 61   2021–2022                     6.1             17.1
# 62   2022–2023                       6             16.5
#
#    Nursing Inpatient Services Intensive Care Nursing Unit Operating Room  \
# 45                       18.2                           5            6.2
# 46                       18.2                         5.1            6.3
# 47                       18.3                         5.2            6.3
# 48                       17.9                         5.1            6.2
# 49                       17.9                         5.1            6.9
# 50                         18                         4.8            6.9
# 51                         18                         4.8            6.9
# 52                       17.9                         4.8            6.8
# 53                       17.7                         4.6            6.8
# 54                       17.6                         4.6            6.7
# 55                       17.3                         4.6            6.5
# 56                       17.3                         4.5            6.6
# 57                       17.2                         4.6            6.5
# 58                       17.4                         4.6            6.6
# 59                       17.2                         4.6            6.4
# 60                       16.8                         4.6            5.7
# 61                       16.8                         4.7            5.8
# 62                       17.3                         4.5            6.2
#
#    Long-Term Care Nursing Unit Emergency Other Ambulatory Care Services  \
# 45                         3.8       3.9                            8.8
# 46                         3.7         4                            8.8
# 47                         3.6       4.1                            9.1
# 48                         3.7         4                            8.9
# 49                         2.9       4.1                            7.9
# 50                         2.8       4.2                              8
# 51                         2.8       4.2                              8
# 52                         2.7       4.2                            8.1
# 53                         2.6       4.2                            8.1
# 54                         2.5       4.2                            8.3
# 55                         2.5       4.2                            8.4
# 56                         2.4       4.2                            8.2
# 57                         2.4       4.3                            8.3
# 58                         2.3       4.2                            8.4
# 59                         2.3       4.3                            8.8
# 60                         2.3       4.1                            8.5
# 61                         2.3       4.1                            8.6
# 62                         2.2       4.3                            8.9
#
#    Medical Imaging Other Diagnostic and Therapeutic Community Health Services  \
# 45               6                             12.5                       2.8
# 46               6                             12.4                       2.8
# 47             5.8                             12.2                       2.8
# 48             5.8                             12.5                       2.8
# 49             5.8                             12.5                       3.6
# 50             5.7                             12.5                       3.7
# 51             5.5                             12.3                       3.7
# 52             5.5                             12.3                       3.7
# 53             5.4                             12.4                       3.9
# 54             5.4                             12.4                         4
# 55             5.3                             12.4                         4
# 56             5.3                             12.5                       4.1
# 57             5.3                             12.5                       4.2
# 58             5.2                             12.4                       4.3
# 59             5.2                             12.4                       4.3
# 60             4.9                             11.9                       5.5
# 61               5                             11.9                       5.9
# 62             4.9                             11.5                       5.3
#
#    Research, Education \nand Other  Total
# 45                              9.1   100
# 46                              8.9   100
# 47                              8.9   100
# 48                              9.5   100
# 49                              9.5   100
# 50                              9.7   100
# 51                             10.2   100
# 52                             10.7   100
# 53                               11   100
# 54                             11.4   100
# 55                               12   100
# 56                               12   100
# 57                             12.3   100
# 58                             12.2   100
# 59                             12.6   100
# 60                             11.8   100
# 61                             11.8   100
# 62                             12.4   100

# %% [markdown]
# ## Annual Percentage Change by Year
# Percentage distribution of hospital spending by service area

# %%
# Canada
can_service_annual = can_df.loc[65:82] 
print(can_service_annual)

# Drop columns containing any NaN values
can_service_annual_cleaned = can_service_annual.dropna(axis=1, how='all')
print(can_service_annual_cleaned)
# Out:
#           Year Administrative Services Support Services  \
# 65  2005–2006                      NaN              NaN
# 66  2006–2007                      3.2              1.5
# 67   2007–2008                       0              0.2
# 68  2008–2009                      0.6              0.2
# 69   2009–2010                    -2.5             -1.1
# 70  2010–2011                     -6.2              0.1
# 71   2011–2012                    -0.1              0.7
# 72  2012–2013                     -1.1              0.1
# 73   2013–2014                    -2.6              0.7
# 74   2014–2015                    -2.4             -0.5
# 75   2015–2016                    -0.4              0.4
# 76   2016–2017                     0.6             -0.2
# 77   2017–2018                    -1.2             -1.6
# 78   2018–2019                     1.2              0.2
# 79   2019–2020                    -3.9               -1
# 80   2020–2021                     5.2              2.8
# 81   2021–2022                    -2.8             -0.4
# 82   2022–2023                     1.1                1
#
#    Nursing Inpatient Services Intensive Care Nursing Unit Operating Room  \
# 65                        NaN                         NaN            NaN
# 66                        1.2                         2.2            2.3
# 67                        0.9                           1            1.3
# 68                       -1.4                        -0.3             -1
# 69                       -0.4                        -0.8            8.8
# 70                        0.3                          -1            0.1
# 71                        0.6                        -0.7           -0.4
# 72                        0.5                         0.5           -0.9
# 73                         -1                        -1.8            0.3
# 74                       -0.3                         0.8           -1.2
# 75                       -0.5                        -0.5           -1.4
# 76                       -0.9                        -0.3           -0.1
# 77                       -0.8                        -0.1           -0.2
# 78                        0.1                        -0.2            1.4
# 79                       -0.9                         0.1           -1.4
# 80                       -0.9                         0.7           -8.6
# 81                       -0.3                         3.6            1.1
# 82                        2.1                        -4.5            6.3
#
#    Long-Term Care Nursing Unit Emergency Other Ambulatory Care Services  \
# 65                         NaN       NaN                            NaN
# 66                        -0.7       3.9                            1.3
# 67                        -4.3         3                            2.4
# 68                        -2.2       0.3                           -0.1
# 69                         -20       1.5                           -8.3
# 70                         0.5       0.1                            2.5
# 71                        -5.1       1.7                            1.6
# 72                          -6      -0.2                           -2.8
# 73                        -9.5       2.2                            0.7
# 74                        -5.1       1.2                            1.1
# 75                        -2.6       0.5                            1.5
# 76                        -5.4       1.3                            1.5
# 77                        -1.3       0.4                            0.9
# 78                        -2.7       0.2                              1
# 79                         0.1       0.9                            3.7
# 80                         0.1         1                             -1
# 81                         1.3      -0.1                           -0.2
# 82                        -5.2       3.5                            1.5
#
#    Medical Imaging Other Diagnostic and Therapeutic Community Health Services  \
# 65             NaN                              NaN                       NaN
# 66             0.6                              1.6                      -2.6
# 67            -2.1                             -1.9                      -2.1
# 68             1.3                              0.2                       2.9
# 69            -6.9                                3                      32.8
# 70               2                             -2.4                       2.2
# 71            -3.7                             -0.4                      -7.3
# 72            -1.6                             -0.2                      -1.2
# 73            -1.1                              1.1                       7.8
# 74            -0.5                                0                       3.5
# 75            -0.2                              1.4                       4.4
# 76             0.1                             -2.1                       1.5
# 77            -1.8                              0.7                       1.7
# 78            -0.3                               -2                       4.2
# 79             0.9                              1.3                      -3.3
# 80            -3.9                             -2.1                      16.1
# 81             0.9                              0.5                       7.5
# 82            -1.4                             -3.4                      -7.6
#
#    Research, Education \nand Other  Total Unnamed: 14
# 65                              NaN   NaN         NaN
# 66                            -14.9     0         NaN
# 67                             -0.9     0         NaN
# 68                              2.9     0         NaN
# 69                                6     0         NaN
# 70                              3.3     0         NaN
# 71                              3.1     0         NaN
# 72                              5.9     0         NaN
# 73                              0.7     0         NaN
# 74                              2.3     0         NaN
# 75                             -2.4     0         NaN
# 76                              4.1     0         NaN
# 77                                4     0         NaN
# 78                             -1.2     0         NaN
# 79                              2.1     0         NaN
# 80                             -1.1     0         NaN
# 81                             -3.7     0         NaN
# 82                             -1.4     0         NaN
#           Year Administrative Services Support Services  \
# 65  2005–2006                      NaN              NaN
# 66  2006–2007                      3.2              1.5
# 67   2007–2008                       0              0.2
# 68  2008–2009                      0.6              0.2
# 69   2009–2010                    -2.5             -1.1
# 70  2010–2011                     -6.2              0.1
# 71   2011–2012                    -0.1              0.7
# 72  2012–2013                     -1.1              0.1
# 73   2013–2014                    -2.6              0.7
# 74   2014–2015                    -2.4             -0.5
# 75   2015–2016                    -0.4              0.4
# 76   2016–2017                     0.6             -0.2
# 77   2017–2018                    -1.2             -1.6
# 78   2018–2019                     1.2              0.2
# 79   2019–2020                    -3.9               -1
# 80   2020–2021                     5.2              2.8
# 81   2021–2022                    -2.8             -0.4
# 82   2022–2023                     1.1                1
#
#    Nursing Inpatient Services Intensive Care Nursing Unit Operating Room  \
# 65                        NaN                         NaN            NaN
# 66                        1.2                         2.2            2.3
# 67                        0.9                           1            1.3
# 68                       -1.4                        -0.3             -1
# 69                       -0.4                        -0.8            8.8
# 70                        0.3                          -1            0.1
# 71                        0.6                        -0.7           -0.4
# 72                        0.5                         0.5           -0.9
# 73                         -1                        -1.8            0.3
# 74                       -0.3                         0.8           -1.2
# 75                       -0.5                        -0.5           -1.4
# 76                       -0.9                        -0.3           -0.1
# 77                       -0.8                        -0.1           -0.2
# 78                        0.1                        -0.2            1.4
# 79                       -0.9                         0.1           -1.4
# 80                       -0.9                         0.7           -8.6
# 81                       -0.3                         3.6            1.1
# 82                        2.1                        -4.5            6.3
#
#    Long-Term Care Nursing Unit Emergency Other Ambulatory Care Services  \
# 65                         NaN       NaN                            NaN
# 66                        -0.7       3.9                            1.3
# 67                        -4.3         3                            2.4
# 68                        -2.2       0.3                           -0.1
# 69                         -20       1.5                           -8.3
# 70                         0.5       0.1                            2.5
# 71                        -5.1       1.7                            1.6
# 72                          -6      -0.2                           -2.8
# 73                        -9.5       2.2                            0.7
# 74                        -5.1       1.2                            1.1
# 75                        -2.6       0.5                            1.5
# 76                        -5.4       1.3                            1.5
# 77                        -1.3       0.4                            0.9
# 78                        -2.7       0.2                              1
# 79                         0.1       0.9                            3.7
# 80                         0.1         1                             -1
# 81                         1.3      -0.1                           -0.2
# 82                        -5.2       3.5                            1.5
#
#    Medical Imaging Other Diagnostic and Therapeutic Community Health Services  \
# 65             NaN                              NaN                       NaN
# 66             0.6                              1.6                      -2.6
# 67            -2.1                             -1.9                      -2.1
# 68             1.3                              0.2                       2.9
# 69            -6.9                                3                      32.8
# 70               2                             -2.4                       2.2
# 71            -3.7                             -0.4                      -7.3
# 72            -1.6                             -0.2                      -1.2
# 73            -1.1                              1.1                       7.8
# 74            -0.5                                0                       3.5
# 75            -0.2                              1.4                       4.4
# 76             0.1                             -2.1                       1.5
# 77            -1.8                              0.7                       1.7
# 78            -0.3                               -2                       4.2
# 79             0.9                              1.3                      -3.3
# 80            -3.9                             -2.1                      16.1
# 81             0.9                              0.5                       7.5
# 82            -1.4                             -3.4                      -7.6
#
#    Research, Education \nand Other  Total
# 65                              NaN   NaN
# 66                            -14.9     0
# 67                             -0.9     0
# 68                              2.9     0
# 69                                6     0
# 70                              3.3     0
# 71                              3.1     0
# 72                              5.9     0
# 73                              0.7     0
# 74                              2.3     0
# 75                             -2.4     0
# 76                              4.1     0
# 77                                4     0
# 78                             -1.2     0
# 79                              2.1     0
# 80                             -1.1     0
# 81                             -3.7     0
# 82                             -1.4     0

# %%
# Ontario
on_service_annual = on_df.loc[65:82]

# Drop columns containing any NaN values
on_service_annual_cleaned = on_service_annual.dropna(axis=1, how='all')
print(on_service_annual_cleaned)
# Out:
#           Year Administrative Services Support Services  \
# 65  2005–2006                      NaN              NaN
# 66  2006–2007                      2.9             -1.1
# 67   2007–2008                     0.3             -1.2
# 68  2008–2009                      0.4                0
# 69   2009–2010                     1.7             -0.1
# 70  2010–2011                       -2              0.1
# 71   2011–2012                    -2.6              0.2
# 72  2012–2013                     -1.8                0
# 73   2013–2014                      -1              0.2
# 74   2014–2015                    -3.2             -1.7
# 75   2015–2016                    -0.2             -0.5
# 76   2016–2017                    -0.9              0.7
# 77   2017–2018                     0.3             -1.9
# 78   2018–2019                    -0.7             -0.8
# 79   2019–2020                    -1.7               -2
# 80   2020–2021                     8.8                9
# 81   2021–2022                    -3.2             -2.9
# 82   2022–2023                    -1.7             -3.5
#
#    Nursing Inpatient Services Intensive Care Nursing Unit Operating Room  \
# 65                        NaN                         NaN            NaN
# 66                          0                         1.9            1.9
# 67                        0.6                         2.1            0.4
# 68                       -2.2                        -1.7           -2.6
# 69                        0.3                        -1.1           12.2
# 70                        0.6                        -5.1            0.1
# 71                       -0.2                         0.2           -0.3
# 72                       -0.6                        -0.6           -1.8
# 73                       -1.1                        -3.5           -0.4
# 74                       -0.6                        -0.8             -1
# 75                       -1.8                        -0.7           -2.3
# 76                        0.1                        -0.4            0.2
# 77                       -0.4                         0.6           -0.6
# 78                        1.1                         0.1            0.5
# 79                         -1                         0.5           -2.1
# 80                       -2.4                         0.7          -11.9
# 81                       -0.2                         1.7            2.4
# 82                          3                        -4.1            7.4
#
#    Long-Term Care Nursing Unit Emergency Other Ambulatory Care Services  \
# 65                         NaN       NaN                            NaN
# 66                        -2.8       1.3                            0.3
# 67                        -1.9       1.5                              4
# 68                         1.1      -1.2                           -2.5
# 69                       -21.3         3                            -11
# 70                        -3.6       1.8                            1.3
# 71                        -0.5      -0.2                           -0.3
# 72                        -1.9      -1.1                            1.7
# 73                        -3.6       0.7                           -0.4
# 74                        -3.5       0.7                            2.7
# 75                        -1.9      -0.9                            0.6
# 76                        -2.1       0.7                           -1.7
# 77                        -3.2         1                            0.6
# 78                          -2      -0.2                              2
# 79                        -1.1       0.4                            4.4
# 80                        -1.1      -3.8                           -3.1
# 81                         1.2      -0.5                            0.9
# 82                        -2.7       5.3                            3.1
#
#    Medical Imaging Other Diagnostic and Therapeutic Community Health Services  \
# 65             NaN                              NaN                       NaN
# 66               0                             -0.2                       0.3
# 67            -2.6                             -2.1                       1.1
# 68             0.1                              2.3                       0.3
# 69            -0.8                              0.1                      28.8
# 70            -1.4                             -0.1                       2.4
# 71            -2.4                             -1.2                        -1
# 72            -1.4                             -0.3                       0.9
# 73            -0.9                              0.8                       4.2
# 74            -0.7                              0.5                       3.9
# 75            -1.1                                0                       0.2
# 76               0                              0.6                       2.1
# 77            -0.9                             -0.3                       2.1
# 78            -0.7                             -0.4                       2.4
# 79            -0.7                             -0.5                       0.9
# 80            -6.1                             -4.1                      26.8
# 81             2.3                              0.3                       6.8
# 82            -1.7                             -3.2                       -10
#
#    Research, Education \nand Other  Total
# 65                              NaN   NaN
# 66                             -1.9     0
# 67                                0     0
# 68                              6.2     0
# 69                              0.3     0
# 70                                2     0
# 71                              5.8     0
# 72                              4.2     0
# 73                              3.1     0
# 74                              3.3     0
# 75                                6     0
# 76                             -0.5     0
# 77                              3.1     0
# 78                             -1.6     0
# 79                              3.3     0
# 80                             -5.7     0
# 81                             -0.7     0
# 82                              5.1     0

# %% [markdown]
# # Write out cleaned data tables to csv

# %%
if not os.path.exists('cleaned_data'):
    os.mkdir('cleaned_data')
    print('A new folder was created.')
else:
    print('This path exists!')
# Out:
# This path exists!

# %%
can_expenses_cleaned.to_csv('./cleaned_data/can-net-expenses.csv', index=False) 
on_expenses_cleaned.to_csv('./cleaned_data/on-net-expenses.csv', index=False) 

can_percentchange_cleaned.to_csv('./cleaned_data/can-spending-percent-change.csv', index=False) 
on_percentchange_cleaned.to_csv('./cleaned_data/on-spending-percent-change.csv', index=False) 

can_service_cleaned.to_csv('./cleaned_data/can-distribution-percent-change.csv', index=False) 
on_service_cleaned.to_csv('./cleaned_data/on-distribution-percent-change.csv', index=False) 

can_service_annual_cleaned.to_csv('./cleaned_data/can-distribution-annual-percent-change.csv', index=False) 
on_service_annual_cleaned.to_csv('./cleaned_data/on-distribution-annual-percent-change.csv', index=False)
